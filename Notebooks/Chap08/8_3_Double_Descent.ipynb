# %% [markdown]
# <a href="https://colab.research.google.com/github/darpanattri/CSCI-167/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-aooth9jo
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-aooth9jo
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=7822dbce85021f06ef24fcbf7c609509ad72d62c94eeec0771c64268edf31b5c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jjlghax3/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# Answer 1: Training error will become zero around n_hidden ≈ 70–100
#
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
#
# Answer 2: First minimum of the double descent curve will appear around n_hidden ≈ 30–50
#
# 3. At what capacity do you expect the maximum of the double descent curve to appear?
#
# Answer 3: Maximum of the double descent curve will appear around n_hidden ≈ 100–200

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.303751, train error 89.40,  test loss 2.303540, test error 89.38
# Epoch   100, train loss 1.928408, train error 73.75,  test loss 1.765146, test error 70.65
# Epoch   200, train loss 1.905353, train error 71.05,  test loss 1.754671, test error 69.15
# Epoch   300, train loss 1.902283, train error 71.15,  test loss 1.759223, test error 70.65
# Epoch   400, train loss 1.896166, train error 70.72,  test loss 1.735273, test error 70.10
# Epoch   500, train loss 1.895076, train error 71.45,  test loss 1.724669, test error 69.07
# Epoch   600, train loss 1.904078, train error 71.15,  test loss 1.765120, test error 70.90
# Epoch   700, train loss 1.894408, train error 70.55,  test loss 1.729062, test error 69.72
# Epoch   800, train loss 1.889966, train error 71.28,  test loss 1.735298, test error 69.45
# Epoch   900, train loss 1.888250, train error 69.82,  test loss 1.730527, test error 68.47
# Training model with   4 hidden variables
# Epoch     0, train loss 2.294261, train error 87.88,  test loss 2.288925, test error 87.57
# Epoch   100, train loss 1.848097, train error 68.85,  test loss 1.708748, test error 67.78
# Epoch   200, train loss 1.839640, train error 68.18,  test loss 1.699951, test error 66.93
# Epoch   300, train loss 1.828696, train error 67.80,  test loss 1.688844, test error 66.28
# Epoch   400, train loss 1.825733, train error 67.00,  test loss 1.695300, test error 66.32
# Epoch   500, train loss 1.824322, train error 67.55,  test loss 1.690662, test error 67.20
# Epoch   600, train loss 1.823557, train error 67.12,  test loss 1.691735, test error 66.25
# Epoch   700, train loss 1.822607, train error 67.55,  test loss 1.688921, test error 66.72
# Epoch   800, train loss 1.821847, train error 67.75,  test loss 1.693148, test error 66.78
# Epoch   900, train loss 1.822471, train error 67.97,  test loss 1.693542, test error 67.28
# Training model with   6 hidden variables
# Epoch     0, train loss 2.288143, train error 87.43,  test loss 2.293352, test error 86.60
# Epoch   100, train loss 1.771837, train error 63.28,  test loss 1.684590, test error 63.60
# Epoch   200, train loss 1.727562, train error 61.58,  test loss 1.631861, test error 61.15
# Epoch   300, train loss 1.677687, train error 59.72,  test loss 1.584164, test error 60.10
# Epoch   400, train loss 1.660858, train error 59.20,  test loss 1.586731, test error 59.25
# Epoch   500, train loss 1.644412, train error 58.85,  test loss 1.583527, test error 59.47
# Epoch   600, train loss 1.638225, train error 58.55,  test loss 1.571023, test error 59.17
# Epoch   700, train loss 1.630980, train error 57.50,  test loss 1.568631, test error 58.62
# Epoch   800, train loss 1.632117, train error 57.30,  test loss 1.565179, test error 57.58
# Epoch   900, train loss 1.629645, train error 57.38,  test loss 1.568814, test error 58.78
# Training model with   8 hidden variables
# Epoch     0, train loss 2.137820, train error 80.15,  test loss 2.076385, test error 78.38
# Epoch   100, train loss 1.490173, train error 50.17,  test loss 1.292900, test error 46.85
# Epoch   200, train loss 1.442873, train error 48.55,  test loss 1.264040, test error 46.10
# Epoch   300, train loss 1.434215, train error 48.70,  test loss 1.270280, test error 46.97
# Epoch   400, train loss 1.423303, train error 48.22,  test loss 1.268371, test error 46.90
# Epoch   500, train loss 1.421679, train error 48.17,  test loss 1.269330, test error 46.75
# Epoch   600, train loss 1.413932, train error 47.78,  test loss 1.277080, test error 46.53
# Epoch   700, train loss 1.415516, train error 47.75,  test loss 1.298371, test error 46.58
# Epoch   800, train loss 1.417763, train error 47.70,  test loss 1.301560, test error 47.25
# Epoch   900, train loss 1.409139, train error 47.83,  test loss 1.294710, test error 47.28
# Training model with  10 hidden variables
# Epoch     0, train loss 2.254818, train error 82.88,  test loss 2.236023, test error 81.05
# Epoch   100, train loss 1.514357, train error 50.53,  test loss 1.342787, test error 49.50
# Epoch   200, train loss 1.454115, train error 48.28,  test loss 1.305834, test error 48.78
# Epoch   300, train loss 1.419834, train error 48.40,  test loss 1.296741, test error 48.22
# Epoch   400, train loss 1.402842, train error 47.95,  test loss 1.301026, test error 48.20
# Epoch   500, train loss 1.391313, train error 47.00,  test loss 1.319098, test error 49.08
# Epoch   600, train loss 1.381973, train error 46.67,  test loss 1.328017, test error 49.38
# Epoch   700, train loss 1.379438, train error 46.85,  test loss 1.342792, test error 49.62
# Epoch   800, train loss 1.371692, train error 46.70,  test loss 1.356034, test error 50.00
# Epoch   900, train loss 1.370218, train error 46.88,  test loss 1.367328, test error 49.53
# Training model with  14 hidden variables
# Epoch     0, train loss 2.273406, train error 85.05,  test loss 2.258003, test error 84.60
# Epoch   100, train loss 1.484447, train error 50.17,  test loss 1.400359, test error 52.40
# Epoch   200, train loss 1.398758, train error 47.25,  test loss 1.350316, test error 49.70
# Epoch   300, train loss 1.344143, train error 45.85,  test loss 1.361491, test error 49.58
# Epoch   400, train loss 1.314900, train error 44.72,  test loss 1.373963, test error 49.35
# Epoch   500, train loss 1.299479, train error 44.08,  test loss 1.402367, test error 49.40
# Epoch   600, train loss 1.277179, train error 43.58,  test loss 1.408283, test error 49.33
# Epoch   700, train loss 1.268380, train error 43.70,  test loss 1.443018, test error 49.55
# Epoch   800, train loss 1.260310, train error 43.12,  test loss 1.439921, test error 50.00
# Epoch   900, train loss 1.262382, train error 42.88,  test loss 1.462353, test error 50.55
# Training model with  18 hidden variables
# Epoch     0, train loss 2.228837, train error 81.82,  test loss 2.215082, test error 81.88
# Epoch   100, train loss 1.314690, train error 43.67,  test loss 1.266542, test error 46.60
# Epoch   200, train loss 1.220461, train error 39.90,  test loss 1.286052, test error 46.35
# Epoch   300, train loss 1.175372, train error 38.78,  test loss 1.341228, test error 47.92
# Epoch   400, train loss 1.151396, train error 38.15,  test loss 1.393793, test error 50.33
# Epoch   500, train loss 1.139577, train error 38.35,  test loss 1.436121, test error 49.60
# Epoch   600, train loss 1.127766, train error 37.88,  test loss 1.448706, test error 49.12
# Epoch   700, train loss 1.116044, train error 38.17,  test loss 1.482354, test error 50.20
# Epoch   800, train loss 1.112794, train error 37.67,  test loss 1.513965, test error 49.83
# Epoch   900, train loss 1.116864, train error 38.72,  test loss 1.563235, test error 51.33
# Training model with  22 hidden variables
# Epoch     0, train loss 2.254004, train error 83.18,  test loss 2.259747, test error 82.60
# Epoch   100, train loss 1.238213, train error 40.97,  test loss 1.321931, test error 48.50
# Epoch   200, train loss 1.126387, train error 37.33,  test loss 1.405803, test error 50.55
# Epoch   300, train loss 1.073599, train error 35.32,  test loss 1.441022, test error 50.88
# Epoch   400, train loss 1.044727, train error 34.82,  test loss 1.510753, test error 51.62
# Epoch   500, train loss 1.030381, train error 34.75,  test loss 1.559473, test error 51.75
# Epoch   600, train loss 1.009696, train error 34.43,  test loss 1.595818, test error 52.17
# Epoch   700, train loss 0.999174, train error 34.32,  test loss 1.626343, test error 52.40
# Epoch   800, train loss 0.980842, train error 33.47,  test loss 1.674899, test error 52.35
# Epoch   900, train loss 0.978332, train error 33.20,  test loss 1.710241, test error 51.65
# Training model with  26 hidden variables
# Epoch     0, train loss 2.148993, train error 80.40,  test loss 2.148276, test error 80.65
# Epoch   100, train loss 1.180283, train error 39.38,  test loss 1.293226, test error 47.78
# Epoch   200, train loss 1.040685, train error 34.60,  test loss 1.388350, test error 48.62
# Epoch   300, train loss 0.978741, train error 31.65,  test loss 1.487716, test error 49.70
# Epoch   400, train loss 0.931362, train error 31.25,  test loss 1.613731, test error 50.65
# Epoch   500, train loss 0.903172, train error 29.95,  test loss 1.686217, test error 51.85
# Epoch   600, train loss 0.875867, train error 29.20,  test loss 1.747025, test error 51.70
# Epoch   700, train loss 0.867060, train error 29.38,  test loss 1.808401, test error 52.08
# Epoch   800, train loss 0.841123, train error 27.78,  test loss 1.856047, test error 52.42
# Epoch   900, train loss 0.843751, train error 29.03,  test loss 1.939812, test error 52.33
# Training model with  30 hidden variables
# Epoch     0, train loss 2.121896, train error 79.20,  test loss 2.071134, test error 77.62
# Epoch   100, train loss 1.100490, train error 35.00,  test loss 1.287386, test error 46.53
# Epoch   200, train loss 0.935535, train error 30.70,  test loss 1.467255, test error 49.62
# Epoch   300, train loss 0.851722, train error 28.88,  test loss 1.728324, test error 52.90
# Epoch   400, train loss 0.789588, train error 26.53,  test loss 1.859539, test error 53.15
# Epoch   500, train loss 0.757034, train error 25.43,  test loss 2.021230, test error 53.35
# Epoch   600, train loss 0.735517, train error 25.05,  test loss 2.132279, test error 54.65
# Epoch   700, train loss 0.689000, train error 23.10,  test loss 2.240473, test error 54.50
# Epoch   800, train loss 0.702009, train error 24.22,  test loss 2.391368, test error 55.25
# Epoch   900, train loss 0.665992, train error 22.55,  test loss 2.516592, test error 54.92
# Training model with  35 hidden variables
# Epoch     0, train loss 2.136259, train error 79.43,  test loss 2.101548, test error 77.32
# Epoch   100, train loss 0.986772, train error 32.00,  test loss 1.389929, test error 49.60
# Epoch   200, train loss 0.755055, train error 24.95,  test loss 1.685515, test error 51.25
# Epoch   300, train loss 0.667013, train error 22.12,  test loss 2.015244, test error 51.80
# Epoch   400, train loss 0.572178, train error 18.35,  test loss 2.329801, test error 52.70
# Epoch   500, train loss 0.534797, train error 17.18,  test loss 2.576296, test error 53.30
# Epoch   600, train loss 0.490477, train error 15.82,  test loss 2.818350, test error 53.75
# Epoch   700, train loss 0.472165, train error 16.00,  test loss 3.104458, test error 54.53
# Epoch   800, train loss 0.459306, train error 15.20,  test loss 3.366194, test error 55.12
# Epoch   900, train loss 0.450471, train error 14.82,  test loss 3.617424, test error 55.80
# Training model with  40 hidden variables
# Epoch     0, train loss 2.119074, train error 77.62,  test loss 2.081347, test error 77.93
# Epoch   100, train loss 0.915444, train error 28.72,  test loss 1.442957, test error 49.30
# Epoch   200, train loss 0.628183, train error 19.45,  test loss 1.940925, test error 51.67
# Epoch   300, train loss 0.493555, train error 15.22,  test loss 2.575887, test error 53.70
# Epoch   400, train loss 0.417421, train error 13.72,  test loss 3.256757, test error 56.05
# Epoch   500, train loss 0.332741, train error 10.68,  test loss 3.879139, test error 56.28
# Epoch   600, train loss 0.288351, train error 9.53,  test loss 4.542446, test error 55.92
# Epoch   700, train loss 0.299252, train error 10.62,  test loss 5.242054, test error 57.35
# Epoch   800, train loss 0.254601, train error 9.43,  test loss 5.667504, test error 56.53
# Epoch   900, train loss 0.301042, train error 10.60,  test loss 6.285992, test error 56.80
# Training model with  45 hidden variables
# Epoch     0, train loss 2.089520, train error 77.95,  test loss 2.040008, test error 78.10
# Epoch   100, train loss 0.771604, train error 24.85,  test loss 1.530144, test error 50.00
# Epoch   200, train loss 0.471511, train error 15.10,  test loss 2.329118, test error 52.28
# Epoch   300, train loss 0.303345, train error 9.40,  test loss 3.405120, test error 54.70
# Epoch   400, train loss 0.213584, train error 7.20,  test loss 4.810951, test error 55.70
# Epoch   500, train loss 0.127096, train error 3.88,  test loss 6.026442, test error 55.55
# Epoch   600, train loss 0.021613, train error 0.03,  test loss 7.233010, test error 55.83
# Epoch   700, train loss 0.012725, train error 0.00,  test loss 8.136698, test error 55.40
# Epoch   800, train loss 0.008483, train error 0.00,  test loss 8.795072, test error 55.83
# Epoch   900, train loss 0.006378, train error 0.00,  test loss 9.288713, test error 55.85
# Training model with  50 hidden variables
# Epoch     0, train loss 2.079876, train error 76.95,  test loss 2.047216, test error 78.28
# Epoch   100, train loss 0.716247, train error 22.22,  test loss 1.572603, test error 51.42
# Epoch   200, train loss 0.335824, train error 10.70,  test loss 2.649222, test error 53.42
# Epoch   300, train loss 0.107141, train error 1.57,  test loss 4.165556, test error 54.85
# Epoch   400, train loss 0.025591, train error 0.03,  test loss 5.618108, test error 55.08
# Epoch   500, train loss 0.012859, train error 0.00,  test loss 6.511173, test error 55.20
# Epoch   600, train loss 0.008276, train error 0.00,  test loss 7.104034, test error 55.62
# Epoch   700, train loss 0.005973, train error 0.00,  test loss 7.544718, test error 55.62
# Epoch   800, train loss 0.004611, train error 0.00,  test loss 7.904862, test error 55.53
# Epoch   900, train loss 0.003740, train error 0.00,  test loss 8.201303, test error 55.58
# Training model with  55 hidden variables
# Epoch     0, train loss 2.065117, train error 76.50,  test loss 2.023713, test error 76.40
# Epoch   100, train loss 0.640474, train error 19.40,  test loss 1.637635, test error 51.97
# Epoch   200, train loss 0.219082, train error 5.53,  test loss 3.091739, test error 55.17
# Epoch   300, train loss 0.035618, train error 0.00,  test loss 4.883601, test error 56.42
# Epoch   400, train loss 0.013873, train error 0.00,  test loss 5.881879, test error 56.38
# Epoch   500, train loss 0.008021, train error 0.00,  test loss 6.493712, test error 56.55
# Epoch   600, train loss 0.005568, train error 0.00,  test loss 6.930442, test error 56.85
# Epoch   700, train loss 0.004160, train error 0.00,  test loss 7.275743, test error 56.97
# Epoch   800, train loss 0.003303, train error 0.00,  test loss 7.553836, test error 56.83
# Epoch   900, train loss 0.002707, train error 0.00,  test loss 7.796440, test error 56.83
# Training model with  60 hidden variables
# Epoch     0, train loss 2.079268, train error 76.40,  test loss 2.014039, test error 75.12
# Epoch   100, train loss 0.503905, train error 14.57,  test loss 1.735519, test error 51.83
# Epoch   200, train loss 0.102675, train error 1.22,  test loss 3.317599, test error 52.95
# Epoch   300, train loss 0.019453, train error 0.00,  test loss 4.612298, test error 53.65
# Epoch   400, train loss 0.009278, train error 0.00,  test loss 5.278276, test error 53.90
# Epoch   500, train loss 0.005906, train error 0.00,  test loss 5.712889, test error 54.05
# Epoch   600, train loss 0.004235, train error 0.00,  test loss 6.032670, test error 54.20
# Epoch   700, train loss 0.003293, train error 0.00,  test loss 6.291601, test error 54.35
# Epoch   800, train loss 0.002629, train error 0.00,  test loss 6.501425, test error 54.22
# Epoch   900, train loss 0.002190, train error 0.00,  test loss 6.681300, test error 54.17
# Training model with  70 hidden variables
# Epoch     0, train loss 2.024752, train error 74.90,  test loss 1.928450, test error 73.18
# Epoch   100, train loss 0.368561, train error 9.10,  test loss 1.861654, test error 52.30
# Epoch   200, train loss 0.033828, train error 0.00,  test loss 3.442557, test error 53.60
# Epoch   300, train loss 0.011117, train error 0.00,  test loss 4.183935, test error 53.58
# Epoch   400, train loss 0.006169, train error 0.00,  test loss 4.618546, test error 54.03
# Epoch   500, train loss 0.004127, train error 0.00,  test loss 4.912835, test error 54.22
# Epoch   600, train loss 0.003048, train error 0.00,  test loss 5.134110, test error 54.17
# Epoch   700, train loss 0.002390, train error 0.00,  test loss 5.315747, test error 54.12
# Epoch   800, train loss 0.001951, train error 0.00,  test loss 5.468297, test error 54.12
# Epoch   900, train loss 0.001642, train error 0.00,  test loss 5.600620, test error 54.12
# Training model with  80 hidden variables
# Epoch     0, train loss 2.045022, train error 76.28,  test loss 1.998925, test error 74.57
# Epoch   100, train loss 0.271977, train error 6.20,  test loss 2.033958, test error 51.70
# Epoch   200, train loss 0.021350, train error 0.00,  test loss 3.359843, test error 52.83
# Epoch   300, train loss 0.008292, train error 0.00,  test loss 3.942125, test error 53.20
# Epoch   400, train loss 0.004857, train error 0.00,  test loss 4.291374, test error 53.42
# Epoch   500, train loss 0.003328, train error 0.00,  test loss 4.532963, test error 53.47
# Epoch   600, train loss 0.002497, train error 0.00,  test loss 4.719074, test error 53.45
# Epoch   700, train loss 0.001978, train error 0.00,  test loss 4.873295, test error 53.58
# Epoch   800, train loss 0.001627, train error 0.00,  test loss 5.004258, test error 53.65
# Epoch   900, train loss 0.001374, train error 0.00,  test loss 5.114285, test error 53.62
# Training model with  90 hidden variables
# Epoch     0, train loss 2.010796, train error 73.55,  test loss 1.959147, test error 74.45
# Epoch   100, train loss 0.159133, train error 1.70,  test loss 2.155492, test error 51.15
# Epoch   200, train loss 0.015168, train error 0.00,  test loss 3.263254, test error 51.95
# Epoch   300, train loss 0.006614, train error 0.00,  test loss 3.706492, test error 52.10
# Epoch   400, train loss 0.004025, train error 0.00,  test loss 3.979852, test error 52.45
# Epoch   500, train loss 0.002829, train error 0.00,  test loss 4.173426, test error 52.55
# Epoch   600, train loss 0.002149, train error 0.00,  test loss 4.327152, test error 52.67
# Epoch   700, train loss 0.001716, train error 0.00,  test loss 4.451428, test error 52.65
# Epoch   800, train loss 0.001420, train error 0.00,  test loss 4.556084, test error 52.65
# Epoch   900, train loss 0.001205, train error 0.00,  test loss 4.647448, test error 52.60
# Training model with 100 hidden variables
# Epoch     0, train loss 1.987339, train error 72.45,  test loss 1.927525, test error 72.55
# Epoch   100, train loss 0.088945, train error 0.10,  test loss 2.265474, test error 50.78
# Epoch   200, train loss 0.012122, train error 0.00,  test loss 3.085276, test error 51.12
# Epoch   300, train loss 0.005659, train error 0.00,  test loss 3.436276, test error 51.08
# Epoch   400, train loss 0.003521, train error 0.00,  test loss 3.660333, test error 51.17
# Epoch   500, train loss 0.002506, train error 0.00,  test loss 3.823897, test error 50.95
# Epoch   600, train loss 0.001918, train error 0.00,  test loss 3.950176, test error 51.03
# Epoch   700, train loss 0.001542, train error 0.00,  test loss 4.056365, test error 51.10
# Epoch   800, train loss 0.001281, train error 0.00,  test loss 4.145291, test error 51.12
# Epoch   900, train loss 0.001091, train error 0.00,  test loss 4.221131, test error 51.00
# Training model with 120 hidden variables
# Epoch     0, train loss 1.961369, train error 73.05,  test loss 1.883239, test error 72.72
# Epoch   100, train loss 0.053172, train error 0.00,  test loss 2.126321, test error 48.42
# Epoch   200, train loss 0.009591, train error 0.00,  test loss 2.712159, test error 48.55
# Epoch   300, train loss 0.004721, train error 0.00,  test loss 2.975435, test error 48.83
# Epoch   400, train loss 0.003019, train error 0.00,  test loss 3.146023, test error 48.70
# Epoch   500, train loss 0.002176, train error 0.00,  test loss 3.274138, test error 48.67
# Epoch   600, train loss 0.001683, train error 0.00,  test loss 3.374620, test error 48.58
# Epoch   700, train loss 0.001362, train error 0.00,  test loss 3.459192, test error 48.62
# Epoch   800, train loss 0.001137, train error 0.00,  test loss 3.529321, test error 48.60
# Epoch   900, train loss 0.000972, train error 0.00,  test loss 3.590818, test error 48.62
# Training model with 140 hidden variables
# Epoch     0, train loss 1.956724, train error 73.03,  test loss 1.875652, test error 73.70
# Epoch   100, train loss 0.035906, train error 0.00,  test loss 2.068862, test error 47.90
# Epoch   200, train loss 0.008055, train error 0.00,  test loss 2.529308, test error 47.97
# Epoch   300, train loss 0.004134, train error 0.00,  test loss 2.749775, test error 47.88
# Epoch   400, train loss 0.002684, train error 0.00,  test loss 2.891743, test error 47.90
# Epoch   500, train loss 0.001955, train error 0.00,  test loss 2.998744, test error 47.92
# Epoch   600, train loss 0.001518, train error 0.00,  test loss 3.082768, test error 48.10
# Epoch   700, train loss 0.001233, train error 0.00,  test loss 3.152772, test error 47.97
# Epoch   800, train loss 0.001032, train error 0.00,  test loss 3.213269, test error 47.97
# Epoch   900, train loss 0.000884, train error 0.00,  test loss 3.266055, test error 48.05
# Training model with 160 hidden variables
# Epoch     0, train loss 1.939680, train error 70.60,  test loss 1.876898, test error 72.15
# Epoch   100, train loss 0.028742, train error 0.00,  test loss 2.168400, test error 48.28
# Epoch   200, train loss 0.007128, train error 0.00,  test loss 2.602798, test error 48.15
# Epoch   300, train loss 0.003750, train error 0.00,  test loss 2.811739, test error 48.00
# Epoch   400, train loss 0.002462, train error 0.00,  test loss 2.949045, test error 47.95
# Epoch   500, train loss 0.001802, train error 0.00,  test loss 3.052511, test error 47.85
# Epoch   600, train loss 0.001406, train error 0.00,  test loss 3.135115, test error 47.88
# Epoch   700, train loss 0.001145, train error 0.00,  test loss 3.203011, test error 47.88
# Epoch   800, train loss 0.000961, train error 0.00,  test loss 3.260740, test error 47.85
# Epoch   900, train loss 0.000825, train error 0.00,  test loss 3.311849, test error 47.88
# Training model with 180 hidden variables
# Epoch     0, train loss 1.928821, train error 70.93,  test loss 1.850250, test error 71.70
# Epoch   100, train loss 0.024239, train error 0.00,  test loss 2.041644, test error 48.12
# Epoch   200, train loss 0.006593, train error 0.00,  test loss 2.391651, test error 48.35
# Epoch   300, train loss 0.003524, train error 0.00,  test loss 2.566719, test error 48.33
# Epoch   400, train loss 0.002334, train error 0.00,  test loss 2.684359, test error 48.33
# Epoch   500, train loss 0.001718, train error 0.00,  test loss 2.771581, test error 48.25
# Epoch   600, train loss 0.001346, train error 0.00,  test loss 2.842576, test error 48.28
# Epoch   700, train loss 0.001099, train error 0.00,  test loss 2.901386, test error 48.22
# Epoch   800, train loss 0.000924, train error 0.00,  test loss 2.952287, test error 48.20
# Epoch   900, train loss 0.000794, train error 0.00,  test loss 2.996500, test error 48.28
# Training model with 200 hidden variables
# Epoch     0, train loss 1.938842, train error 71.20,  test loss 1.873950, test error 72.45
# Epoch   100, train loss 0.022897, train error 0.00,  test loss 2.069156, test error 48.03
# Epoch   200, train loss 0.006289, train error 0.00,  test loss 2.397335, test error 48.30
# Epoch   300, train loss 0.003401, train error 0.00,  test loss 2.565738, test error 48.20
# Epoch   400, train loss 0.002263, train error 0.00,  test loss 2.680970, test error 48.28
# Epoch   500, train loss 0.001669, train error 0.00,  test loss 2.767680, test error 48.42
# Epoch   600, train loss 0.001310, train error 0.00,  test loss 2.836267, test error 48.42
# Epoch   700, train loss 0.001071, train error 0.00,  test loss 2.894506, test error 48.53
# Epoch   800, train loss 0.000901, train error 0.00,  test loss 2.944511, test error 48.47
# Epoch   900, train loss 0.000775, train error 0.00,  test loss 2.987837, test error 48.45
# Training model with 250 hidden variables
# Epoch     0, train loss 1.910048, train error 71.00,  test loss 1.817120, test error 70.90
# Epoch   100, train loss 0.017350, train error 0.00,  test loss 1.862096, test error 46.90
# Epoch   200, train loss 0.005401, train error 0.00,  test loss 2.110921, test error 46.72
# Epoch   300, train loss 0.002990, train error 0.00,  test loss 2.244025, test error 46.62
# Epoch   400, train loss 0.002017, train error 0.00,  test loss 2.335151, test error 46.50
# Epoch   500, train loss 0.001500, train error 0.00,  test loss 2.404520, test error 46.53
# Epoch   600, train loss 0.001184, train error 0.00,  test loss 2.460238, test error 46.50
# Epoch   700, train loss 0.000971, train error 0.00,  test loss 2.507166, test error 46.53
# Epoch   800, train loss 0.000820, train error 0.00,  test loss 2.547322, test error 46.58
# Epoch   900, train loss 0.000707, train error 0.00,  test loss 2.582837, test error 46.67
# Training model with 300 hidden variables
# Epoch     0, train loss 1.865577, train error 67.12,  test loss 1.797770, test error 70.82
# Epoch   100, train loss 0.014660, train error 0.00,  test loss 1.858714, test error 47.05
# Epoch   200, train loss 0.004842, train error 0.00,  test loss 2.082084, test error 46.88
# Epoch   300, train loss 0.002744, train error 0.00,  test loss 2.201759, test error 47.03
# Epoch   400, train loss 0.001864, train error 0.00,  test loss 2.282771, test error 46.97
# Epoch   500, train loss 0.001394, train error 0.00,  test loss 2.345475, test error 46.95
# Epoch   600, train loss 0.001104, train error 0.00,  test loss 2.395864, test error 46.92
# Epoch   700, train loss 0.000908, train error 0.00,  test loss 2.438315, test error 46.85
# Epoch   800, train loss 0.000768, train error 0.00,  test loss 2.475186, test error 46.80
# Epoch   900, train loss 0.000664, train error 0.00,  test loss 2.507179, test error 46.78
# Training model with 400 hidden variables
# Epoch     0, train loss 1.837494, train error 66.32,  test loss 1.785051, test error 69.70
# Epoch   100, train loss 0.011749, train error 0.00,  test loss 1.763340, test error 44.97
# Epoch   200, train loss 0.004182, train error 0.00,  test loss 1.936262, test error 44.92
# Epoch   300, train loss 0.002424, train error 0.00,  test loss 2.033487, test error 45.03
# Epoch   400, train loss 0.001669, train error 0.00,  test loss 2.101350, test error 45.12
# Epoch   500, train loss 0.001258, train error 0.00,  test loss 2.153776, test error 45.20
# Epoch   600, train loss 0.001002, train error 0.00,  test loss 2.196493, test error 45.30
# Epoch   700, train loss 0.000828, train error 0.00,  test loss 2.232114, test error 45.22
# Epoch   800, train loss 0.000703, train error 0.00,  test loss 2.262930, test error 45.22
# Epoch   900, train loss 0.000609, train error 0.00,  test loss 2.290457, test error 45.22

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
